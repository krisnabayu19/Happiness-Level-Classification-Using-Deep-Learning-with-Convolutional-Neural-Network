# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Activation, Dropout
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('D:\Deep Learning\dataset_tingkat_kebahagiaan.csv')
df.head()
# Out:
#    sentimen                                              Tweet
# 0         1  providername pakai providername paket productn...
# 1         1  providername providername kangen nih kiriman p...
# 2         1  alhamdulillah setia providername menari tabuha...
# 3         1                      asik kencang providername url
# 4         1                      mantap g lte providername url

# %%
text = df["Tweet"].tolist()
print(len(text))
# Out:
# 2268

# %%
y = df["sentimen"]
y = to_categorical(y)
print(y)
# Out:
# [[0. 1.]
#  [0. 1.]
#  [0. 1.]
#  ...
#  [1. 0.]
#  [1. 0.]
#  [1. 0.]]

# %%
df["sentimen"].value_counts()
# Out:
# 0    1134
# 1    1134
# Name: sentimen, dtype: int64

# %%
token = Tokenizer()
token.fit_on_texts(text)

# %%
token.index_word
# Out:
# {1: 'enak',
#  2: 'tempat',
#  3: 'makanan',
#  4: 'makan',
#  5: 'harga',
#  6: 'menu',
#  7: 'bandung',
#  8: 'cukup',
#  9: 'nyaman',
#  10: 'rasanya',
#  11: 'suka',
#  12: 'rasa',
#  13: 'restoran',
#  14: 'pelayanan',
#  15: 'kecewa',
#  16: 'suasana',
#  17: 'malam',
#  18: 'bagus',
#  19: 'goreng',
#  20: 'marah',
#  21: 'jalan',
#  22: 'mahal',
#  23: 'satu',
#  24: 'salah',
#  25: 'sih',
#  26: 'nasi',
#  27: 'bikin',
#  28: 'keluarga',
#  29: 'pemandangan',
#  30: 'pas',
#  31: 'datang',
#  32: 'ayam',
#  33: 'steak',
#  34: 'indosat',
#  35: 'hari',
#  36: 'lumayan',
#  37: 'pilihan',
#  38: 'pesan',
#  39: 'kurang',
#  40: 'porsi',
#  41: 'mantap',
#  42: 'baik',
#  43: 'tahu',
#  44: 'anak',
#  45: 'cocok',
#  46: 'film',
#  47: 'kota',
#  48: 'kali',
#  49: 'lokasi',
#  50: 'kafe',
#  51: 'ramah',
#  52: 'baru',
#  53: 'minuman',
#  54: 'pakai',
#  55: 'waktu',
#  56: 'resto',
#  57: 'melihat',
#  58: 'bosan',
#  59: 'besar',
#  60: 'indonesia',
#  61: 'teman',
#  62: 'providername',
#  63: 'memesan',
#  64: 'jam',
#  65: 'khas',
#  66: 'pelayan',
#  67: 'mi',
#  68: 'daging',
#  69: 'membuat',
#  70: 'bakar',
#  71: 'ternyata',
#  72: 'terus',
#  73: 'mati',
#  74: 'oke',
#  75: 'luar',
#  76: 'kesal',
#  77: 'terjangkau',
#  78: 'masakan',
#  79: 'sambal',
#  80: 'segar',
#  81: 'murah',
#  82: 'langsung',
#  83: 'goblok',
#  84: 'luas',
#  85: 'sayang',
#  86: 'keren',
#  87: 'favorit',
#  88: 'pedas',
#  89: 'coba',
#  90: 'sunda',
#  91: 'cepat',
#  92: 'bakso',
#  93: 'siang',
#  94: 'ramai',
#  95: 'tahun',
#  96: 'pertama',
#  97: 'gila',
#  98: 'the',
#  99: 'otak',
#  100: 'pak',
#  101: 'menikmati',
#  102: 'jokowi',
#  103: 'kasih',
#  104: 'punya',
#  105: 'menjadi',
#  106: 'menurut',
#  107: 'masuk',
#  108: 'mencoba',
#  109: 'senang',
#  110: 'malu',
#  111: 'sesuai',
#  112: 'unik',
#  113: 'rekomendasi',
#  114: 'kopi',
#  115: 'nih',
#  116: 'rumah',
#  117: 'duduk',
#  118: 'atas',
#  119: 'bumbu',
#  120: 'jauh',
#  121: 'ikan',
#  122: 'sate',
#  123: 'parkir',
#  124: 'menunggu',
#  125: 'dicoba',
#  126: 'pagi',
#  127: 'gua',
#  128: 'kuah',
#  129: 'lemah',
#  130: 'lupa',
#  131: 'asik',
#  132: 'nonton',
#  133: 'disajikan',
#  134: 'beragam',
#  135: 'nongkrong',
#  136: 'hati',
#  137: 'bodoh',
#  138: 'beli',
#  139: 'babi',
#  140: 'dago',
#  141: 'tetap',
#  142: 'terkenal',
#  143: 'takut',
#  144: 'hotel',
#  145: 'berada',
#  146: 'semoga',
#  147: 'kemarin',
#  148: 'bersih',
#  149: 'es',
#  150: 'terasa',
#  151: 'ditambah',
#  152: 'kotor',
#  153: 'ribu',
#  154: 'pasangan',
#  155: 'daerah',
#  156: 'nama',
#  157: 'minum',
#  158: 'benarbenar',
#  159: 'pokok',
#  160: 'udara',
#  161: 'meja',
#  162: 'berkunjung',
#  163: 'roti',
#  164: 'manis',
#  165: 'jakarta',
#  166: 'buka',
#  167: 'sedih',
#  168: 'kualitas',
#  169: 'lidah',
#  170: 'minggu',
#  171: 'mulai',
#  172: 'terima',
#  173: 'lihat',
#  174: 'kayak',
#  175: 'perlu',
#  176: 'mata',
#  177: 'terutama',
#  178: 'standar',
#  179: 'romantis',
#  180: 'susah',
#  181: 'awal',
#  182: 'dasar',
#  183: 'batagor',
#  184: 'presiden',
#  185: 'benar',
#  186: 'nikmat',
#  187: 'air',
#  188: 'barat',
#  189: 'daun',
#  190: 'berbagai',
#  191: 'bilang',
#  192: 'acara',
#  193: 'rusak',
#  194: 'islam',
#  195: 'pizza',
#  196: 'pengunjung',
#  197: 'bebek',
#  198: 'paket',
#  199: 'hidup',
#  200: 'miskin',
#  201: 'dingin',
#  202: 'indah',
#  203: 'mampir',
#  204: 'kampung',
#  205: 'tersedia',
#  206: 'direkomendasikan',
#  207: 'sinyal',
#  208: 'biar',
#  209: 'username',
#  210: 'secara',
#  211: 'agama',
#  212: 'benci',
#  213: 'malas',
#  214: 'rakyat',
#  215: 'jijik',
#  216: 'bingung',
#  217: 'galau',
#  218: 'lantai',
#  219: 'menarik',
#  220: 'mengecewakan',
#  221: 'saus',
#  222: 'isi',
#  223: 'konsep',
#  224: 'kata',
#  225: 'strategis',
#  226: 'kepiting',
#  227: 'santai',
#  228: 'cara',
#  229: 'ibu',
#  230: 'cantik',
#  231: 'soal',
#  232: 'pelanggan',
#  233: 'anjing',
#  234: 'cemburu',
#  235: 'pilih',
#  236: 'penuh',
#  237: 'teh',
#  238: 'sore',
#  239: 'cari',
#  240: 'bawa',
#  241: 'memilih',
#  242: 'cinta',
#  243: 'tenang',
#  244: 'beda',
#  245: 'area',
#  246: 'negara',
#  247: 'hambar',
#  248: 'pesanan',
#  249: 'tengah',
#  250: 'mudah',
#  251: 'penyajian',
#  252: 'plus',
#  253: 'jawa',
#  254: 'musik',
#  255: 'dah',
#  256: 'super',
#  257: 'istri',
#  258: 'sehat',
#  259: 'parah',
#  260: 'ahok',
#  261: 'foto',
#  262: 'sejuk',
#  263: 'lezat',
#  264: 'top',
#  265: 'kadang',
#  266: 'bahagia',
#  267: 'kaya',
#  268: 'kebanyakan',
#  269: 'iri',
#  270: 'kacau',
#  271: 'alam',
#  272: 'mencari',
#  273: 'berbeda',
#  274: 'menyesal',
#  275: 'empuk',
#  276: 'jenis',
#  277: 'bubur',
#  278: 'keju',
#  279: 'sop',
#  280: 'warung',
#  281: 'jelas',
#  282: 'kembali',
#  283: 'zaman',
#  284: 'habis',
#  285: 'bayar',
#  286: 'merasa',
#  287: 'kuliner',
#  288: 'menyediakan',
#  289: 'wajib',
#  290: 'terletak',
#  291: 'sempit',
#  292: 'telkomsel',
#  293: 'puas',
#  294: 'main',
#  295: 'hujan',
#  296: 'allah',
#  297: 'mbak',
#  298: 'bagian',
#  299: 'tua',
#  300: 'tinggal',
#  301: 'gurih',
#  302: 'chicken',
#  303: 'mie',
#  304: 'kambing',
#  305: 'muda',
#  306: 'suami',
#  307: 'manusia',
#  308: 'bangga',
#  309: 'sok',
#  310: 'sumpah',
#  311: 'produk',
#  312: 'dua',
#  313: 'jenuh',
#  314: 'menyenangkan',
#  315: 'tradisional',
#  316: 'ala',
#  317: 'temanteman',
#  318: 'memuaskan',
#  319: 'braga',
#  320: 'order',
#  321: 'buntut',
#  322: 'masa',
#  323: 'tolong',
#  324: 'live',
#  325: 'bulan',
#  326: 'naik',
#  327: 'hancur',
#  328: 'kerja',
#  329: 'lembang',
#  330: 'udang',
#  331: 'pasta',
#  332: 'bakmi',
#  333: 'bawah',
#  334: 'hijau',
#  335: 'seafood',
#  336: 'indomie',
#  337: 'cina',
#  338: 'prabowo',
#  339: 'kangen',
#  340: 'jaringan',
#  341: 'n',
#  342: 'kebetulan',
#  343: 'akhir',
#  344: 'jelek',
#  345: 'siap',
#  346: 'barang',
#  347: 'cabang',
#  348: 'letak',
#  349: 'interior',
#  350: 'kenyang',
#  351: 'tea',
#  352: 'aneh',
#  353: 'terbaik',
#  354: 'mah',
#  355: 'bgt',
#  356: 'terlihat',
#  357: 'asli',
#  358: 'keseluruhan',
#  359: 'uang',
#  360: 'pergi',
#  361: 'ukuran',
#  362: 'kue',
#  363: 'bambu',
#  364: 'asin',
#  365: 'wangi',
#  366: 'bervariasi',
#  367: 'lampu',
#  368: 'bangsa',
#  369: 'memberikan',
#  370: 'pulang',
#  371: 'masalah',
#  372: 'berasa',
#  373: 'emosi',
#  374: 'saung',
#  375: 'variasi',
#  376: 'tepat',
#  377: 'perut',
#  378: 'keluar',
#  379: 'sapi',
#  380: 'sarapan',
#  381: 'ruangan',
#  382: 'macet',
#  383: 'indihome',
#  384: 'politik',
#  385: 'setia',
#  386: 'kuota',
#  387: 'pake',
#  388: 'kuat',
#  389: 'sm',
#  390: 'sakit',
#  391: 'sungguh',
#  392: 'dunia',
#  393: 'suara',
#  394: 'dikasih',
#  395: 'pribadi',
#  396: 'ambil',
#  397: 'mobil',
#  398: 'panas',
#  399: 'iga',
#  400: 'umum',
#  401: 'stroberi',
#  402: 'gurame',
#  403: 'minta',
#  404: 'jus',
#  405: 'antre',
#  406: 'desain',
#  407: 'sabar',
#  408: 'klo',
#  409: 'bu',
#  410: 'sekeluarga',
#  411: 'bapak',
#  412: 'mu',
#  413: 'selera',
#  414: 'hukum',
#  415: 'belakang',
#  416: 'termasuk',
#  417: 'terakhir',
#  418: 'riau',
#  419: 'ketagihan',
#  420: 'lanjutan',
#  421: 'bareng',
#  422: 'anakanak',
#  423: 'garagara',
#  424: 'utama',
#  425: 'bali',
#  426: 'penasaran',
#  427: 'kantong',
#  428: 'bersahabat',
#  429: 'menambah',
#  430: 'ditawarkan',
#  431: 'mahasiswa',
#  432: 'tinggi',
#  433: 'penting',
#  434: 'org',
#  435: 'baca',
#  436: 'gangguan',
#  437: 'menit',
#  438: 'ganti',
#  439: 'lewat',
#  440: 'berat',
#  441: 'kalah',
#  442: 'orangorang',
#  443: 'gara',
#  444: 'enakenak',
#  445: 'hidangan',
#  446: 'penutup',
#  447: 'disediakan',
#  448: 'dibilang',
#  449: 'sajian',
#  450: 'negeri',
#  451: 'menggunakan',
#  452: 'terdapat',
#  453: 'hehe',
#  454: 'diberikan',
#  455: 'kursi',
#  456: 'berubah',
#  457: 'ramen',
#  458: 'rica',
#  459: 'jne',
#  460: 'gratis',
#  461: 'mending',
#  462: 'belanja',
#  463: 'an',
#  464: 'promo',
#  465: 'kartu',
#  466: 'kedua',
#  467: 'mas',
#  468: 'asal',
#  469: 'perempuan',
#  470: 'halal',
#  471: 'to',
#  472: 'layak',
#  473: 'hitam',
#  474: 'usah',
#  475: 'situ',
#  476: 'ribet',
#  477: 'menginap',
#  478: 'tenderloin',
#  479: 'pusat',
#  480: 'menyajikan',
#  481: 'sekadar',
#  482: 'pisang',
#  483: 'membawa',
#  484: 'memiliki',
#  485: 'istimewa',
#  486: 'telepon',
#  487: 'lengkap',
#  488: 'dessert',
#  489: 'layanan',
#  490: 'wow',
#  491: 'sayur',
#  492: 'asri',
#  493: 'fpi',
#  494: 'selamat',
#  495: 'internet',
#  496: 'hebat',
#  497: 'tiba',
#  498: 'lagu',
#  499: 'mba',
#  500: 'melakukan',
#  501: 'per',
#  502: 'muka',
#  503: 'gini',
#  504: 'berani',
#  505: 'bakal',
#  506: 'cerita',
#  507: 'tolol',
#  508: 'masak',
#  509: 'sistem',
#  510: 'relatif',
#  511: 'dusun',
#  512: 'tiket',
#  513: 'kolam',
#  514: 'juara',
#  515: 'cumi',
#  516: 'warga',
#  517: 'tamu',
#  518: 'lapar',
#  519: 's',
#  520: 'dipakai',
#  521: 'soup',
#  522: 'mengobrol',
#  523: 'krim',
#  524: 'a',
#  525: 'mushroom',
#  526: 'kasir',
#  527: 'kosong',
#  528: 'menawarkan',
#  529: 'ringan',
#  530: 'spesial',
#  531: 'tambahan',
#  532: 'kesan',
#  533: 'menemukan',
#  534: 'tibatiba',
#  535: 'gubernur',
#  536: 'hilang',
#  537: 'janji',
#  538: 'pemerintah',
#  539: 'youtube',
#  540: 'puasa',
#  541: 'lancar',
#  542: 'lucu',
#  543: 'beliau',
#  544: 'artis',
#  545: 'memberi',
#  546: 'ulang',
#  547: 'alami',
#  548: 'calon',
#  549: 'jevin',
#  550: 'tv',
#  551: 'loh',
#  552: 'tim',
#  553: 'pki',
#  554: 'mulut',
#  555: 'alasan',
#  556: 'doang',
#  557: 'menonton',
#  558: 'dengki',
#  559: 'asam',
#  560: 'piring',
#  561: 'mal',
#  562: 'menuju',
#  563: 'sayuran',
#  564: 'kuning',
#  565: 'lembut',
#  566: 'campur',
#  567: 'coklat',
#  568: 'khusus',
#  569: 'daftar',
#  570: 'bau',
#  571: 'beef',
#  572: 'mengunjungi',
#  573: 'kantor',
#  574: 'wisata',
#  575: 'nkri',
#  576: 'hasil',
#  577: 'oh',
#  578: 'partai',
#  579: 'g',
#  580: 'pulsa',
#  581: 'pintu',
#  582: 'bs',
#  583: 'kondisi',
#  584: 'pihak',
#  585: 'laki',
#  586: 'jujur',
#  587: 'terkesan',
#  588: 'arah',
#  589: 'buah',
#  590: 'jatuh',
#  591: 'jawab',
#  592: 'nangis',
#  593: 'pendukung',
#  594: 'buruk',
#  595: 'sensasi',
#  596: 'sederhana',
#  597: 'media',
#  598: 'putih',
#  599: 'masyarakat',
#  600: 'sampah',
#  601: 'say',
#  602: 'buku',
#  603: 'panjang',
#  604: 'tarik',
#  605: 'bermain',
#  606: 'kedai',
#  607: 'saji',
#  608: 'keindahan',
#  609: 'sebaiknya',
#  610: 'kacang',
#  611: 'bangunan',
#  612: 'dekorasi',
#  613: 'dibuat',
#  614: 'variatif',
#  615: 'reservasi',
#  616: 'minimal',
#  617: 'gedung',
#  618: 'makana',
#  619: 'menjual',
#  620: 'cenderung',
#  621: 'penataan',
#  622: 'lauk',
#  623: 'suki',
#  624: 'sebelah',
#  625: 'fotofoto',
#  626: 'surabaya',
#  627: 'melulu',
#  628: 'aduh',
#  629: 'api',
#  630: 'dengar',
#  631: 'gagal',
#  632: 'semangat',
#  633: 'mendukung',
#  634: 'hangat',
#  635: 'ngomong',
#  636: 'jg',
#  637: 'hamil',
#  638: 'nikah',
#  639: 'krn',
#  640: 'seru',
#  641: 'gimana',
#  642: 'pindah',
#  643: 'ditemukan',
#  644: 'penyuka',
#  645: 'sengaja',
#  646: 'jengkel',
#  647: 'dibanding',
#  648: 'it',
#  649: 'merah',
#  650: 'dpr',
#  651: 'cita',
#  652: 'sofa',
#  653: 'terbilang',
#  654: 'toilet',
#  655: 'setiabudi',
#  656: 'parkiran',
#  657: 'yummy',
#  658: 'jepang',
#  659: 'kentang',
#  660: 'pinggir',
#  661: 'sepadan',
#  662: 'persis',
#  663: 'kayu',
#  664: 'kalinya',
#  665: 'peak',
#  666: 'ramahramah',
#  667: 'modern',
#  668: 'kering',
#  669: 'akses',
#  670: 'kiosk',
#  671: 'rawon',
#  672: 'balik',
#  673: 'restaurant',
#  674: 'mendapatkan',
#  675: 'selesai',
#  676: 'sepi',
#  677: 'ruang',
#  678: 'tom',
#  679: 'salad',
#  680: 'setengah',
#  681: 'lima',
#  682: 'alhamdulillah',
#  683: 'emang',
#  684: 'tidak',
#  685: 'yakin',
#  686: 'wanita',
#  687: 'sukses',
#  688: 'liat',
#  689: 'maju',
#  690: 'dr',
#  691: 'jaman',
#  692: 'proses',
#  693: 'but',
#  694: 'asyik',
#  695: 'diajak',
#  696: 'putus',
#  697: 'in',
#  698: 'd',
#  699: 'ingat',
#  700: 'out',
#  701: 'kasian',
#  702: 'dinikmati',
#  703: 'malang',
#  704: 'kelakuan',
#  705: 'dipilih',
#  706: 'tidur',
#  707: 'mendapat',
#  708: 'sedap',
#  709: 'kena',
#  710: 'gede',
#  711: 'kasihan',
#  712: 'sempurna',
#  713: 'anies',
#  714: 'bicara',
#  715: 'sulit',
#  716: 'non',
#  717: 'kamar',
#  718: 'dijual',
#  719: 'tema',
#  720: 'pecinta',
#  721: 'bersantai',
#  722: 'ditemani',
#  723: 'antrean',
#  724: 'jual',
#  725: 'cobalah',
#  726: 'level',
#  727: 'potongan',
#  728: 'kawasan',
#  729: 'staf',
#  730: 'garing',
#  731: 'x',
#  732: 'bukit',
#  733: 'tempe',
#  734: 'diberi',
#  735: 'tipis',
#  736: 'liburan',
#  737: 'laugh',
#  738: 'karyawan',
#  739: 'dipesan',
#  740: 'sup',
#  741: 'butuh',
#  742: 'kehabisan',
#  743: 'potong',
#  744: 'contoh',
#  745: 'berdiri',
#  746: 'hutan',
#  747: 'betah',
#  748: 'burger',
#  749: 'merokok',
#  750: 'kulit',
#  751: 'jogja',
#  752: 'muak',
#  753: 'lgbt',
#  754: 'muslim',
#  755: 'umat',
#  756: 'muhammad',
#  757: 'kencang',
#  758: 'url',
#  759: 'ikutan',
#  760: 'kecepatan',
#  761: 'aman',
#  762: 'paham',
#  763: 'suaranya',
#  764: 'cuaca',
#  765: 'bener',
#  766: 'tp',
#  767: 'ama',
#  768: 'ikut',
#  769: 'dy',
#  770: 'pesawat',
#  771: 'membaca',
#  772: 'sikap',
#  773: 'ditanya',
#  774: 'gw',
#  775: 'saking',
#  776: 'aurel',
#  777: 'skrg',
#  778: 'keras',
#  779: 'gojek',
#  780: 'he',
#  781: 'lokal',
#  782: 'bangsat',
#  783: 'sebagian',
#  784: 'pikir',
#  785: 'heran',
#  786: 'bodo',
#  787: 'maluin',
#  788: 'lelah',
#  789: 'pakar',
#  790: 'kira',
#  791: 'najwa',
#  792: 'sari',
#  793: 'meriah',
#  794: 'setimpal',
#  795: 'macammacam',
#  796: 'terjun',
#  797: 'pangsit',
#  798: 'nuansa',
#  799: 'merasakan',
#  800: 'servis',
#  801: 'th',
#  802: 'lainlain',
#  803: 'berlokasi',
#  804: 'menghabiskan',
#  805: 'andalan',
#  806: 'berkualitas',
#  807: 'okelah',
#  808: 'suis',
#  809: 'potato',
#  810: 'cream',
#  811: 'ice',
#  812: 'aroma',
#  813: 'berkumpul',
#  814: 'adem',
#  815: 'toko',
#  816: 'mendoan',
#  817: 'ribuan',
#  818: 'jajanan',
#  819: 'upnormal',
#  820: 'aneka',
#  821: 'kecap',
#  822: 'kunjungan',
#  823: 'demokrat',
#  824: 'kesukaan',
#  825: 'gaya',
#  826: 'dijadikan',
#  827: 'bisnis',
#  828: 'ngobrol',
#  829: 'genggam',
#  830: 'menghadap',
#  831: 'susu',
#  832: 'menjadikan',
#  833: 'perjalanan',
#  834: 'jalanan',
#  835: 'njungi',
#  836: 'dll',
#  837: 'tutup',
#  838: 'ratarata',
#  839: 'kangkung',
#  840: 'tanggal',
#  841: 'siomay',
#  842: 'capek',
#  843: 'mengatakan',
#  844: 'melayani',
#  845: 'barbeque',
#  846: 'betul',
#  847: 'tol',
#  848: 'busuk',
#  849: 'pssi',
#  850: 'belajar',
#  851: 'amin',
#  852: 'via',
#  853: 'bang',
#  854: 'abis',
#  855: 'ma',
#  856: 'dikit',
#  857: 'blm',
#  858: 'apapun',
#  859: 'music',
#  860: 'model',
#  861: 'kenyataan',
#  862: 'ni',
#  863: 'lho',
#  864: 'anaknya',
#  865: 'bela',
#  866: 'keadaan',
#  867: 'pohon',
#  868: 'pemain',
#  869: 'kartini',
#  870: 'guys',
#  871: 'ekspektasi',
#  872: 'nomor',
#  873: 'sopan',
#  874: 'pemimpin',
#  875: 'pelakor',
#  876: 'mikir',
#  877: 'bacot',
#  878: 'munafik',
#  879: 'nilai',
#  880: 'ragu',
#  881: 'terang',
#  882: 'bertemu',
#  883: 'ekonomi',
#  884: 'turun',
#  885: 'kickandy',
#  886: 'anggota',
#  887: 'rindu',
#  888: 'curiga',
#  889: 'khawatir',
#  890: 'pengalaman',
#  891: 'garang',
#  892: 'berupa',
#  893: 'sapu',
#  894: 'serasa',
#  895: 'sawah',
#  896: 'jamur',
#  897: 'menyegarkan',
#  898: 'sebanding',
#  899: 'rekan',
#  900: 'sambel',
#  901: 'bihun',
#  902: 'posisi',
#  903: 'memanjakan',
#  904: 'tuna',
#  905: 'pertemuan',
#  906: 'mengenyangkan',
#  907: 'dimasak',
#  908: 'hang',
#  909: 'serabi',
#  910: 'kuliah',
#  911: 'cabe',
#  912: 'telur',
#  913: 'menengah',
#  914: 'disarankan',
#  915: 'membantu',
#  916: 'meresap',
#  917: 'dikunjungi',
#  918: 'rupiah',
#  919: 'belanda',
#  920: 'rapi',
#  921: 'ciwalk',
#  922: 'green',
#  923: 'renyah',
#  924: 'liwet',
#  925: 'merayakan',
#  926: 'permainan',
#  927: 'dukung',
#  928: 'wine',
#  929: 'musim',
#  930: 'lift',
#  931: 'simpang',
#  932: 'dicari',
#  933: 'ac',
#  934: 'samping',
#  935: 'tunggu',
#  936: 'kendaraan',
#  937: 'terbuka',
#  938: 'gang',
#  939: 'istana',
#  940: 'plaza',
#  941: 'mandi',
#  942: 'yam',
#  943: 'info',
#  944: 'dijangkau',
#  945: 'berlamalama',
#  946: 'pasar',
#  947: 'pekan',
#  948: 'lotek',
#  949: 'tebu',
#  950: 'karedok',
#  951: 'akal',
#  952: 'pukul',
#  953: 'rp',
#  954: 'lontong',
#  955: 'berharap',
#  956: 'betutu',
#  957: 'bandrek',
#  958: 'gula',
#  959: 'kaki',
#  960: 'pengin',
#  961: 'oleholeh',
#  962: 'pilkada',
#  963: 'sungai',
#  964: 'fahri',
#  965: 'bubarkan',
#  966: 'kristen',
#  967: 'kekuasaan',
#  968: 'sinetron',
#  969: 'bonus',
#  970: 'normal',
#  971: 'video',
#  972: 'tata',
#  973: 'ngapain',
#  974: 'mengambil',
#  975: 'mikirin',
#  976: 'budaya',
#  977: 'cucu',
#  978: 'tercinta',
#  979: 'sby',
#  980: 'generasi',
#  981: 'polos',
#  982: 'mengikuti',
#  983: 'salut',
#  984: 'akhirat',
#  985: 'rini',
#  986: 'natural',
#  987: 'diam',
#  988: 'seni',
#  989: 'milih',
#  990: 'worth',
#  991: 'koneksi',
#  992: 'seminggu',
#  993: 'gambar',
#  994: 'perasaan',
#  995: 'yah',
#  996: 'ampun',
#  997: 'cowok',
#  998: 'pintar',
#  999: 'waras',
#  1000: 'tambah',
#  ...}

# %%
vocab = len(token.index_word)+1
vocab
# Out:
# 7848

# %%
encode_text = token.texts_to_sequences(text)
print(encode_text)
# Out:
# [[62, 54, 62, 198, 1115, 3380, 3381, 198, 1115, 3382, 539, 109, 62], [62, 62, 339, 115, 2216, 1648, 3383, 62, 82, 100, 1648], [682, 385, 62, 3384, 3385, 3386, 494, 3387, 3388], [131, 757, 62, 758], [41, 579, 1649, 62, 758], [3389, 54, 62, 629, 1650, 385, 62, 22, 759, 2217], [62, 41, 3390, 62], [760, 495, 3391, 1651, 41, 62, 3392, 2218, 758], [41, 62, 1652, 3393], [131, 757, 62], [386, 761, 62, 2219, 3394, 47, 3395, 758], [2220, 85, 385, 3396, 3397, 18, 62, 62, 758], [207, 62, 496, 1653, 3398, 141, 1116, 41], [41, 62, 222, 580, 153, 969, 198, 1324, 1117, 3399, 62, 118, 2221, 62, 3400], [198, 1324, 1654, 970, 62, 8, 293, 2221, 62, 62], [172, 103, 62, 62], [62, 173, 539, 3401, 386, 86], [166, 540, 1655, 539, 541, 387, 62, 385, 62], [166, 540, 1655, 539, 541, 54, 62, 385, 62], [172, 103, 2222, 62, 2216, 460, 62, 3402, 497], [227, 54, 62, 3403, 3404, 2223], [385, 3405, 62], [86, 3406, 207, 579, 62], [207, 62, 388], [3407, 62, 3408, 3409, 3410, 109], [682, 385, 62, 353], [207, 579, 1118, 115, 41, 62, 758], [461, 2224, 3411, 630, 254, 1119, 539, 460, 340, 62, 86], [1, 462, 1656, 207, 388, 757, 54, 62], [41, 198, 1115, 62, 27, 3412, 3413], [969, 3414, 969, 62, 115, 27, 136, 109], [2225, 238, 3415, 294, 3416, 207, 541, 496, 683, 62], [265, 239, 1325, 539, 2226, 1326, 86, 62, 539, 463, 386, 1655, 541], [850, 3417, 971, 539, 1, 91, 762, 340, 62, 541, 757], [1657, 3418, 1115, 48, 464, 386, 495, 3419, 385, 62, 71, 682, 2227, 44], [93, 3420, 969, 1658, 54, 465, 62, 52, 761, 541, 2228, 763, 764, 295], [407, 2229, 296, 105, 1120, 581, 3421, 2230, 629, 1659, 466, 3422], [498, 2231, 297, 972, 1660, 3423, 116, 1121, 297, 972, 10, 297, 972, 765, 85, 2232, 2233, 1327, 3424, 146, 2234], [1328, 297, 167, 1329, 3425, 408, 255, 3426, 389, 154, 2235, 3427, 973, 25, 167, 2236, 3428, 3429, 389, 296, 3430, 1661, 3431, 390, 499, 1330, 2237, 766, 1122, 3432, 582, 3433, 583, 1122, 3434, 2238, 191, 408, 266, 2239, 266, 408, 167, 2239, 167, 3435, 208, 97], [11, 154, 23, 146, 2240, 3436, 105, 28, 3437, 3438, 3439, 146, 684, 584, 1662, 2241, 2242, 1662, 3440], [542, 1663, 2243, 3441, 322, 305, 3442, 354, 305, 1664, 1665, 3443, 3444, 3445, 1666, 3446, 3447, 1667, 1123, 3448, 3449, 3450, 585, 1668, 3451, 3452, 1331, 685, 180, 974, 1669, 267, 2243, 3453, 1670, 3454, 3455, 432], [240, 3456, 1671, 3457, 3458, 306, 256, 3459, 3460, 267, 1672, 3461, 8, 1673, 1332, 686, 3462, 975, 106, 1671, 1672, 1124, 105, 2244, 306, 257, 1125, 631, 3463, 1116, 2245, 3464, 1671, 1672, 146, 3465, 2246, 3466, 3467], [632, 3468, 209, 3469, 3470, 1333, 307, 104, 1126, 323, 2247, 3471, 1333, 95], [86, 1674, 3472, 3473, 281, 3474, 389, 28, 184], [184, 3475, 3476, 308], [3477, 1127, 3478, 2248, 3479, 3480, 308, 767, 976, 60], [768, 308, 3481], [11, 355, 389, 3482, 769, 228, 3483, 1675, 2249, 341, 3484, 3485, 3486, 769, 3487], [1128, 2250, 3488, 586, 632, 2250, 496], [687, 72, 1334, 146, 2251, 3489, 296, 1335, 258, 851], [229, 209, 28, 241, 2252, 2253, 2, 192, 28, 59, 298, 1129, 2252, 2253, 587, 124, 1336, 229, 28, 55, 258, 229, 28, 851, 851, 3490], [3491, 2254, 103, 633, 3492, 3493, 1676, 1677, 770, 146, 1337, 3494, 105, 1338, 181, 3495, 3496, 770, 1339, 60, 282, 3497, 1678, 1340, 1130, 3498, 2255, 3499, 770, 3500, 82, 3501, 3502, 3503, 1674], [632, 1678, 1340, 258, 1131, 3504, 296, 3505, 388, 1131, 500, 3506, 146, 1341, 3507, 368, 2256, 1678, 1340], [230, 2257, 258, 409, 2258, 410], [409, 3508, 27, 136, 3509, 339, 3510, 3511, 339, 977, 978], [172, 103, 100, 979, 229, 2258, 1342, 543, 369, 3512, 75, 60, 95, 3513, 266, 258, 3514], [3515, 3516, 48, 771, 3517, 210, 684, 82, 850, 1343, 3518, 2254, 103, 229, 210, 2259, 1132, 3519, 229, 3520, 766, 685, 1679, 3521, 44, 2260, 2261, 229, 105, 980, 368, 1680, 3522, 258, 72, 229, 146, 242, 103, 28, 3523, 3524], [3525, 229, 2262, 410, 2263, 1681, 3526, 28, 229, 3527, 57, 772, 1682, 3528, 28, 229, 391, 2264, 467, 2265, 229, 306, 685, 411, 2266, 184, 543, 308, 411, 634, 3529, 28, 409, 3530, 629, 3531, 1683], [109, 688, 229, 341, 3532, 979, 101, 35, 299, 3 ...

# %%
max_kata = 100
X = pad_sequences(encode_text, maxlen = max_kata, padding="post")
X
# Out:
# array([[  62,   54,   62, ...,    0,    0,    0],
#        [  62,   62,  339, ...,    0,    0,    0],
#        [ 682,  385,   62, ...,    0,    0,    0],
#        ...,
#        [ 234, 1284,    0, ...,    0,    0,    0],
#        [ 310,   15, 1652, ...,    0,    0,    0],
#        [ 126,  126,  847, ...,    0,    0,    0]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=40, test_size = 0.3, stratify=y)

# %%
X_train = np.asarray(X_train)
X_test = np.asarray(X_test)
y_train = np.asarray(y_train)
y_test = np.asarray(y_test)

# %%
vec_size = 300
model = Sequential()
model.add(Embedding(vocab, vec_size, input_length=max_kata))
model.add(Conv1D(64,8,activation="relu"))
model.add(MaxPooling1D(1))
model.add(Dropout(0.5))

model.add(Dense(32, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(16, activation="relu"))
model.add(GlobalMaxPooling1D())
model.add(Dense(2, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_9 (Embedding)      (None, 100, 300)          2354400
# _________________________________________________________________
# conv1d_9 (Conv1D)            (None, 93, 64)            153664
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 93, 64)            0
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 93, 64)            0
# _________________________________________________________________
# dense_24 (Dense)             (None, 93, 32)            2080
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 93, 32)            0
# _________________________________________________________________
# dense_25 (Dense)             (None, 93, 16)            528
# _________________________________________________________________
# global_max_pooling1d_8 (Glob (None, 16)                0
# _________________________________________________________________
# dense_26 (Dense)             (None, 2)                 34
# =================================================================
# Total params: 2,510,706
# Trainable params: 2,510,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 50/50 [==============================] - 7s 103ms/step - loss: 0.6990 - accuracy: 0.5079 - val_loss: 0.6891 - val_accuracy: 0.5007
# Epoch 2/100
# 50/50 [==============================] - 5s 92ms/step - loss: 0.6194 - accuracy: 0.7234 - val_loss: 0.4568 - val_accuracy: 0.8517
# Epoch 3/100
# 50/50 [==============================] - 5s 97ms/step - loss: 0.2056 - accuracy: 0.9319 - val_loss: 0.1637 - val_accuracy: 0.9559
# Epoch 4/100
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0328 - accuracy: 0.9912 - val_loss: 0.1285 - val_accuracy: 0.9545
# Epoch 5/100
# 50/50 [==============================] - 15s 312ms/step - loss: 0.0119 - accuracy: 0.9975 - val_loss: 0.1298 - val_accuracy: 0.9545
# Epoch 6/100
# 50/50 [==============================] - 17s 329ms/step - loss: 0.0055 - accuracy: 0.9994 - val_loss: 0.1309 - val_accuracy: 0.9545
# Epoch 7/100
# 50/50 [==============================] - 7s 132ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.1340 - val_accuracy: 0.9515
# Epoch 8/100
# 50/50 [==============================] - 6s 121ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9471
# Epoch 9/100
# 50/50 [==============================] - 6s 111ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1401 - val_accuracy: 0.9442
# Epoch 10/100
# 50/50 [==============================] - 5s 107ms/step - loss: 8.5621e-04 - accuracy: 1.0000 - val_loss: 0.1421 - val_accuracy: 0.9471
# Epoch 11/100
# 50/50 [==============================] - 5s 104ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1418 - val_accuracy: 0.9471
# Epoch 12/100
# 50/50 [==============================] - 5s 100ms/step - loss: 7.3566e-04 - accuracy: 1.0000 - val_loss: 0.1397 - val_accuracy: 0.9530
# Epoch 13/100
# 50/50 [==============================] - 5s 98ms/step - loss: 9.3185e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9515
# Epoch 14/100
# 50/50 [==============================] - 5s 94ms/step - loss: 3.7306e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9530
# Epoch 15/100
# 50/50 [==============================] - 5s 93ms/step - loss: 5.7343e-04 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9515
# Epoch 16/100
# 50/50 [==============================] - 5s 92ms/step - loss: 3.0167e-04 - accuracy: 1.0000 - val_loss: 0.1501 - val_accuracy: 0.9515
# Epoch 17/100
# 50/50 [==============================] - 5s 93ms/step - loss: 1.8090e-04 - accuracy: 1.0000 - val_loss: 0.1523 - val_accuracy: 0.9515
# Epoch 18/100
# 50/50 [==============================] - 5s 92ms/step - loss: 5.0026e-04 - accuracy: 1.0000 - val_loss: 0.1565 - val_accuracy: 0.9515
# Epoch 19/100
# 50/50 [==============================] - 5s 92ms/step - loss: 8.4538e-05 - accuracy: 1.0000 - val_loss: 0.1592 - val_accuracy: 0.9486
# Epoch 20/100
# 50/50 [==============================] - 5s 93ms/step - loss: 2.5322e-04 - accuracy: 1.0000 - val_loss: 0.1712 - val_accuracy: 0.9471 0s - loss: 2.4064e
# Epoch 21/100
# 50/50 [==============================] - 5s 93ms/step - loss: 4.3857e-04 - accuracy: 1.0000 - val_loss: 0.1671 - val_accuracy: 0.9501
# Epoch 22/100
# 50/50 [==============================] - 5s 93ms/step - loss: 7.9724e-04 - accuracy: 1.0000 - val_loss: 0.1677 - val_accuracy: 0.9427
# Epoch 23/100
# 50/50 [==============================] - 5s 92ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.2194 - val_accuracy: 0.9295
# Epoch 24/100
# 50/50 [==============================] - 5s 93ms/step - loss: 4.8543e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9471
# Epoch 25/100
# 50/50 [==============================] - 5s 92ms/step - loss: 1.9048e-04 - accuracy: 1.0000 - val_loss: 0.1783 - val_accuracy: 0.9486
# Epoch 26/100
# 50/50 [==============================] - 5s 95ms/step - loss: 0.0014 - accuracy: 0.9987 - val_loss: 0.1870 - val_accuracy: 0.9398
# Epoch 27/100
# 50/50 [==============================] - 5s 93ms/step - loss: 3.1364e-04 - accuracy: 1.0000 - val_loss: 0.1958 - val_accuracy: 0.9442
# Epoch 28/100
# 50/50 [==============================] - 5s 93ms/step - loss: 4.0571e-04 - accuracy: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9486
# Epoch 29/100
# 50/50 [==============================] - 5s 94ms/step - loss: 3.5264e-04 - accuracy: 1.0000 - val_loss: 0.2050 - val_accuracy: 0.9427
# Epoch 30/100
# 50/50 [==============================] - 29s 581ms/step - loss: 2.9721e-04 - accuracy: 1.0000 - val_loss: 0.2044 - val_accuracy: 0.9457
# Epoch 31/100
# 50/50 [==============================] - 7s 145ms/step - loss: 2.3278e-04 - accuracy: 1.0000 - val_loss: 0.1993 - val_accuracy: 0.9471
# Epoch 32/100
# 50/50 [==============================] - 6s 125ms/step - loss: 7.0210e-05 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9486
# Epoch 33/100
# 50/50 [==============================] - 6s 115ms/step - loss: 2.7737e-05 - accuracy: 1.0000 - val_loss: 0.2001 - val_accuracy: 0.9471
# Epoch 34/100
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.2909 - val_accuracy: 0.9383
# Epoch 35/100
# 50/50 [==============================] - 5s 106ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.2040 - val_accuracy: 0.9486
# Epoch 36/100
# 50/50 [==============================] - 5s 109ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.2652 - val_accuracy: 0.9457
# Epoch 37/100
# 50/50 [==============================] - 5s 105ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.2920 - val_accuracy: 0.9369
# Epoch 38/100
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.3060 - val_accuracy: 0.9413
# Epoch 39/100
# 50/50 [==============================] - 5s 102ms/step - loss: 0.0039 - accuracy: 0.9994 - val_loss: 0.3366 - val_accuracy: 0.9398
# Epoch 40/100
# 50/50 [==============================] - 5s 101ms/step - loss: 7.7934e-04 - accuracy: 1.0000 - val_loss: 0.3135 - val_accuracy: 0.9295
# Epoch 41/100
# 50/50 [==============================] - 5s 97ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.3362 - val_accuracy: 0.9369acy:
# Epoch 42/100
# 50/50 [==============================] - 5s 94ms/step - loss: 1.3634e-04 - accuracy: 1.0000 - val_loss: 0.3376 - val_accuracy: 0.9354
# Epoch 43/100
# 50/50 [==============================] - 5s 94ms/step - loss: 1.2441e-04 - accuracy: 1.0000 - val_loss: 0.3324 - val_accuracy: 0.9325
# Epoch 44/100
# 50/50 [==============================] - 5s 96ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.3807 - val_accuracy: 0.9383
# Epoch 45/100
# 50/50 [==============================] - 5s 96ms/step - loss: 3.7479e-04 - accuracy: 1.0000 - val_loss: 0.3989 - val_accuracy: 0.9398
# Epoch 46/100
# 50/50 [==============================] - 5s 96ms/step - loss: 9.1924e-05 - accuracy: 1.0000 - val_loss: 0.3663 - val_accuracy: 0.9339
# Epoch 47/100
# 50/50 [==============================] - 5s 96ms/step - loss: 1.4222e-04 - accuracy: 1.0000 - val_loss: 0.3475 - val_accuracy: 0.9413
# Epoch 48/100
# 50/50 [==============================] - 5s 96ms/step - loss: 2.7397e-04 - accuracy: 1.0000 - val_loss: 0.3367 - val_accuracy: 0.9398
# Epoch 49/100
# 50/50 [==============================] - 5s 96ms/step - loss: 1.8891e-04 - accuracy: 1.0000 - val_loss: 0.3403 - val_accuracy: 0.9354
# Epoch 50/100
# 50/50 [==============================] - 5s 97ms/step - loss: 2.8641e-04 - accuracy: 1.0000 - val_loss: 0.3577 - val_accuracy: 0.9325
# Epoch 51/100
# 50/50 [==============================] - 29s 581ms/step - loss: 1.1778e-04 - accuracy: 1.0000 - val_loss: 0.3544 - val_accuracy: 0.9369
# Epoch 52/100
# 50/50 [==============================] - 7s 146ms/step - loss: 8.1390e-05 - accuracy: 1.0000 - val_loss: 0.3523 - val_accuracy: 0.9383
# Epoch 53/100
# 50/50 [==============================] - 6s 126ms/step - loss: 8.3557e-05 - accuracy: 1.0000 - val_loss: 0.3513 - val_accuracy: 0.9383
# Epoch 54/100
# 50/50 [==============================] - 6s 117ms/step - loss: 1.1427e-05 - accuracy: 1.0000 - val_loss: 0.3451 - val_accuracy: 0.9383
# Epoch 55/100
# 50/50 [==============================] - 6s 111ms/step - loss: 2.9989e-05 - accuracy: 1.0000 - val_loss: 0.3375 - val_accuracy: 0.9383
# Epoch 56/100
# 50/50 [==============================] - 5s 107ms/step - loss: 1.5792e-05 - accuracy: 1.0000 - val_loss: 0.3372 - val_accuracy: 0.9369
# Epoch 57/100
# 50/50 [==============================] - 5s 102ms/step - loss: 2.9125e-05 - accuracy: 1.0000 - val_loss: 0.3355 - val_accuracy: 0.9413
# Epoch 58/100
# 50/50 [==============================] - 5s 98ms/step - loss: 2.8419e-04 - accuracy: 1.0000 - val_loss: 0.4520 - val_accuracy: 0.9339
# Epoch 59/100
# 50/50 [==============================] - 5s 96ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.3647 - val_accuracy: 0.9325
# Epoch 60/100
# 50/50 [==============================] - 5s 93ms/step - loss: 2.0996e-05 - accuracy: 1.0000 - val_loss: 0.3700 - val_accuracy: 0.9354
# Epoch 61/100
# 50/50 [==============================] - 5s 93ms/step - loss: 2.5487e-04 - accuracy: 1.0000 - val_loss: 0.3775 - val_accuracy: 0.9383
# Epoch 62/100
# 50/50 [==============================] - 5s 92ms/step - loss: 9.2592e-05 - accuracy: 1.0000 - val_loss: 0.3586 - val_accuracy: 0.9383
# Epoch 63/100
# 50/50 [==============================] - 5s 91ms/step - loss: 1.4140e-05 - accuracy: 1.0000 - val_loss: 0.3573 - val_accuracy: 0.9369
# Epoch 64/100
# 50/50 [==============================] - 5s 92ms/step - loss: 5.3496e-06 - accuracy: 1.0000 - val_loss: 0.3584 - val_accuracy: 0.9354
# Epoch 65/100
# 50/50 [==============================] - 5s 92ms/step - loss: 2.3487e-04 - accuracy: 1.0000 - val_loss: 0.3593 - val_accuracy: 0.9354
# Epoch 66/100
# 50/50 [==============================] - 5s 93ms/step - loss: 1.4248e-05 - accuracy: 1.0000 - val_loss: 0.3579 - val_accuracy: 0.9354
# Epoch 67/100
# 50/50 [==============================] - 5s 93ms/step - loss: 4.5982e-05 - accuracy: 1.0000 - val_loss: 0.3594 - val_accuracy: 0.9339
# Epoch 68/100
# 50/50 [==============================] - 5s 95ms/step - loss: 0.0103 - accuracy: 0.9987 - val_loss: 0.4156 - val_accuracy: 0.9236
# Epoch 69/100
# 50/50 [==============================] - 5s 95ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.5137 - val_accuracy: 0.9207
# Epoch 70/100
# 50/50 [==============================] - 5s 94ms/step - loss: 8.0893e-04 - accuracy: 0.9994 - val_loss: 0.3609 - val_accuracy: 0.93989.1
# Epoch 71/100
# 50/50 [==============================] - 5s 94ms/step - loss: 7.1872e-05 - accuracy: 1.0000 - val_loss: 0.3785 - val_accuracy: 0.9383
# Epoch 72/100
# 50/50 [==============================] - 5s 93ms/step - loss: 2.2070e-04 - accuracy: 1.0000 - val_loss: 0.3693 - val_accuracy: 0.9383ccuracy:  -
# Epoch 73/100
# 50/50 [==============================] - 5s 93ms/step - loss: 5.5192e-05 - accuracy: 1.0000 - val_loss: 0.3749 - val_accuracy: 0.9398
# Epoch 74/100
# 50/50 [==============================] - 5s 93ms/step - loss: 1.7980e-05 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.9383
# Epoch 75/100
# 50/50 [==============================] - 28s 577ms/step - loss: 7.7211e-05 - accuracy: 1.0000 - val_loss: 0.4062 - val_accuracy: 0.9339
# Epoch 76/100
# 50/50 [==============================] - 8s 149ms/step - loss: 2.7379e-05 - accuracy: 1.0000 - val_loss: 0.4132 - val_accuracy: 0.9354
# Epoch 77/100
# 50/50 [==============================] - 6s 125ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.4595 - val_accuracy: 0.9295
# Epoch 78/100
# 50/50 [==============================] - 6s 116ms/step - loss: 3.0229e-06 - accuracy: 1.0000 - val_loss: 0.4349 - val_accuracy: 0.9325
# Epoch 79/100
# 50/50 [==============================] - 5s 109ms/step - loss: 1.8190e-05 - accuracy: 1.0000 - val_loss: 0.4341 - val_accuracy: 0.9339
# Epoch 80/100
# 50/50 [==============================] - 5s 106ms/step - loss: 4.2473e-06 - accuracy: 1.0000 - val_loss: 0.4330 - val_accuracy: 0.9325
# Epoch 81/100
# 50/50 [==============================] - 5s 104ms/step - loss: 1.3330e-04 - accuracy: 1.0000 - val_loss: 0.4865 - val_accuracy: 0.9310
# Epoch 82/100
# 50/50 [==============================] - 5s 104ms/step - loss: 5.5552e-05 - accuracy: 1.0000 - val_loss: 0.4935 - val_accuracy: 0.9310
# Epoch 83/100
# 50/50 [==============================] - 5s 101ms/step - loss: 3.0603e-05 - accuracy: 1.0000 - val_loss: 0.4816 - val_accuracy: 0.9295
# Epoch 84/100
# 50/50 [==============================] - 5s 97ms/step - loss: 3.7010e-05 - accuracy: 1.0000 - val_loss: 0.4914 - val_accuracy: 0.9310
# Epoch 85/100
# 50/50 [==============================] - 5s 99ms/step - loss: 3.9802e-05 - accuracy: 1.0000 - val_loss: 0.4766 - val_accuracy: 0.9280
# Epoch 86/100
# 50/50 [==============================] - 5s 98ms/step - loss: 1.5412e-05 - accuracy: 1.0000 - val_loss: 0.4770 - val_accuracy: 0.9266
# Epoch 87/100
# 50/50 [==============================] - 5s 97ms/step - loss: 9.1309e-05 - accuracy: 1.0000 - val_loss: 0.4772 - val_accuracy: 0.9266
# Epoch 88/100
# 50/50 [==============================] - 5s 98ms/step - loss: 1.3633e-05 - accuracy: 1.0000 - val_loss: 0.4770 - val_accuracy: 0.9295
# Epoch 89/100
# 50/50 [==============================] - 5s 99ms/step - loss: 1.3048e-06 - accuracy: 1.0000 - val_loss: 0.4772 - val_accuracy: 0.9295
# Epoch 90/100
# 50/50 [==============================] - 5s 96ms/step - loss: 1.9760e-05 - accuracy: 1.0000 - val_loss: 0.4752 - val_accuracy: 0.9295
# Epoch 91/100
# 50/50 [==============================] - 5s 96ms/step - loss: 2.7397e-04 - accuracy: 1.0000 - val_loss: 0.5724 - val_accuracy: 0.9222
# Epoch 92/100
# 50/50 [==============================] - 5s 96ms/step - loss: 1.2538e-04 - accuracy: 1.0000 - val_loss: 0.6222 - val_accuracy: 0.9148 1s - los - ETA: 0s - loss: 1.3229e-04 - accuracy
# Epoch 93/100
# 50/50 [==============================] - 5s 97ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.6096 - val_accuracy: 0.9134
# Epoch 94/100
# 50/50 [==============================] - 5s 101ms/step - loss: 9.1526e-04 - accuracy: 0.9994 - val_loss: 0.5376 - val_accuracy: 0.9251
# Epoch 95/100
# 50/50 [==============================] - 5s 99ms/step - loss: 0.0071 - accuracy: 0.9994 - val_loss: 0.7218 - val_accuracy: 0.9266
# Epoch 96/100
# 50/50 [==============================] - 5s 99ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.6153 - val_accuracy: 0.9325
# Epoch 97/100
# 50/50 [==============================] - 5s 99ms/step - loss: 3.6480e-04 - accuracy: 1.0000 - val_loss: 0.5550 - val_accuracy: 0.9339
# Epoch 98/100
# 50/50 [==============================] - 5s 98ms/step - loss: 1.5920e-04 - accuracy: 1.0000 - val_loss: 0.5545 - val_accuracy: 0.9354
# Epoch 99/100
# 50/50 [==============================] - 30s 606ms/step - loss: 2.9397e-05 - accuracy: 1.0000 - val_loss: 0.5625 - val_accuracy: 0.9369
# Epoch 100/100
# 50/50 [==============================] - 7s 148ms/step - loss: 3.5985e-05 - accuracy: 1.0000 - val_loss: 0.5657 - val_accuracy: 0.9339

# %%
def get_encode(x):
    x = token.texts_to_sequences(x)
    x = pad_sequences(x, maxlen = max_kata, padding="post")
    return x

# %%
x = ['saya benci kamu']
x = get_encode(x)

# %%
model.predict_classes(x)
# Out:
# array([0], dtype=int64)
